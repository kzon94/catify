# %% [markdown]
# <a href="https://colab.research.google.com/github/kzon94/catify/blob/main/catify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalar librerías necesarias
# !pip install spotipy python-dotenv requests pandas pillow matplotlib
# Out:
# Requirement already satisfied: spotipy in /usr/local/lib/python3.11/dist-packages (2.25.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.1.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: redis>=3.5.3 in /usr/local/lib/python3.11/dist-packages (from spotipy) (5.2.1)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from spotipy) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 447, in run
#     conflicts = self._determine_conflicts(to_install)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 578, in _determine_conflicts
#     return check_install_conflicts(to_install)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/check.py", line 101, in check_install_conflicts
#     package_set, _ = create_package_set_from_installed()
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/operations/check.py", line 42, in create_package_set_from_installed
#     dependencies = list(dist.iter_dependencies())
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_dists.py", line 219, in iter_dependencies
#     for req_string in self.metadata.get_all("Requires-Dist", []):
#                       ^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/functools.py", line 1001, in __get__
#     val = self.func(instance)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/base.py", line 394, in metadata
#     metadata = self._metadata_impl()
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_dists.py", line 209, in _metadata_impl
#     return cast(email.message.Message, self._dist.metadata)
#                                        ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/metadata/__init__.py", line 617, in metadata
#     return _adapters.Message(email.message_from_string(text))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/__init__.py", line 37, in message_from_string
#     return Parser(*args, **kws).parsestr(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/parser.py", line 67, in parsestr
#     return self.parse(StringIO(text), headersonly=headersonly)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/parser.py", line 56, in parse
#     feedparser.feed(data)
#   File "/usr/lib/python3.11/email/feedparser.py", line 174, in feed
#     self._call_parse()
#   File "/usr/lib/python3.11/email/feedparser.py", line 178, in _call_parse
#     self._parse()
#   File "/usr/lib/python3.11/email/feedparser.py", line 238, in _parsegen
#     self._parse_headers(headers)
#   File "/usr/lib/python3.11/email/feedparser.py", line 486, in _parse_headers
#     self._cur.set_raw(*self.policy.header_source_parse(lastvalue))
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/_policybase.py", line 301, in header_source_parse
#     def header_source_parse(self, sourcelines):
#
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.11/logging/__init__.py", line 1536, in critical
#     self._log(CRITICAL, msg, args, **kwargs)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1634, in _log
#     self.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1644, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1706, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 978, in handle
#     self.emit(record)
#   File "/usr/lib/python3.11/logging/handlers.py", line 75, in emit
#     logging.FileHandler.emit(self, record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1230, in emit
#     StreamHandler.emit(self, record)
#   File "/usr/lib/python3.11/logging/__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/logging/__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/utils/logging.py", line 118, in format
#     prefix = f"{self.formatTime(record)} "
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/logging/__init__.py", line 624, in formatTime
#     ct = self.converter(record.created)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %%
import os
import webbrowser
import requests
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyOAuth
from PIL import Image
import base64
import matplotlib.pyplot as plt

# Configuración de claves y constantes
SPOTIFY_CLIENT_ID = "ee83ec260c504dbfa11eac5eac8709ad"
SPOTIFY_CLIENT_SECRET = "fe5846efd8954b94b2e2df87147eaf2f"
SPOTIFY_REDIRECT_URI = "https://example.org/callback"
SPOTIFY_SCOPE = "playlist-modify-public playlist-modify-private ugc-image-upload"
LASTFM_API_KEY = "73addf297c7f3d0372f11ed3566249bd"
CSV_FILENAME = "songs_recommendations.csv"
IMAGE_PATH = "michis.jpg"

print("\n🔒 Iniciando autenticación en Spotify...")

# Autenticación sin abrir navegador
auth_manager = SpotifyOAuth(
    client_id=SPOTIFY_CLIENT_ID,
    client_secret=SPOTIFY_CLIENT_SECRET,
    redirect_uri=SPOTIFY_REDIRECT_URI,
    scope=SPOTIFY_SCOPE,
    open_browser=False
)

authorize_url = auth_manager.get_authorize_url()
print("\n🔎 Accediendo a URL de autorización...")
# print(authorize_url)

sp = spotipy.Spotify(auth_manager=auth_manager)
print("\n✅ Autenticación completada.")

# Obtener información del usuario
def get_user_info():
    user_info = sp.current_user()
    print(f"\n👤 Usuario autenticado: {user_info['display_name']} (" +
          f"{user_info['external_urls']['spotify']})")
    return user_info['id']

# Generar CSV de recomendaciones
def generate_songs_csv():
    query = input("\n🎵 Ingresa el nombre de la canción y el artista: ")

    # Buscar en Last.fm
    search_url = f"http://ws.audioscrobbler.com/2.0/?method=track.search&track={query}&api_key={LASTFM_API_KEY}&format=json"
    r = requests.get(search_url)
    if r.status_code != 200:
        print("❌ Error al obtener datos de Last.fm.")
        return
    data = r.json()
    if ("results" not in data or "trackmatches" not in data["results"] or
            "track" not in data["results"]["trackmatches"]):
        print("⚠️ No se encontró la canción en Last.fm.")
        return

    first_result = data["results"]["trackmatches"]["track"][0]
    track_name = first_result["name"]
    artist_name = first_result["artist"]
    print(f"\n✅ Encontrada en Last.fm: {track_name} - {artist_name}")

    # Buscar en Spotify
    query_spotify = f"track:{track_name} artist:{artist_name}"
    results = sp.search(q=query_spotify, type="track", limit=1)
    found_songs = []
    if results["tracks"]["items"]:
        track_sp = results["tracks"]["items"][0]
        track_info = {
            "title": track_sp["name"],
            "artist": ", ".join(a["name"] for a in track_sp["artists"]),
            "url": track_sp["external_urls"]["spotify"]
        }
        found_songs.append(track_info)
        print(f"✅ Encontrada en Spotify: {track_info['title']} - {track_info['artist']}")
        print("\n🔎 Canciones similares:\n")
    else:
        print(f"⚠️ No se encontró '{track_name}' - {artist_name} en Spotify.")

    # Canciones similares
    similar_url = f"http://ws.audioscrobbler.com/2.0/?method=track.getsimilar&artist={artist_name}&track={track_name}&api_key={LASTFM_API_KEY}&format=json"
    r = requests.get(similar_url)
    if r.status_code == 200:
        data = r.json()
        if "similartracks" in data and "track" in data["similartracks"]:
            for t in data["similartracks"]["track"][:49]:
                similar_artist = t["artist"]["name"]
                title = t["name"]
                q = f"track:{title} artist:{similar_artist}"
                similar_res = sp.search(q=q, type="track", limit=1)
                if similar_res["tracks"]["items"]:
                    track_sp = similar_res["tracks"]["items"][0]
                    track_info = {
                        "title": track_sp["name"],
                        "artist": ", ".join(a["name"] for a in track_sp["artists"]),
                        "url": track_sp["external_urls"]["spotify"]
                    }
                    found_songs.append(track_info)
                    print(f"{track_info['title']} - {track_info['artist']} ({track_info['url']})")

    df_songs = pd.DataFrame(found_songs)
    df_songs.to_csv(CSV_FILENAME, index=False)
    print(f"\n📁 CSV generado en: {CSV_FILENAME}")

# Crear playlist
def create_playlist(user_id):
    playlist_name = input("\n📋 Nombre de la nueva playlist: ")
    playlist = sp.user_playlist_create(
        user=user_id,
        name=playlist_name,
        public=True,
        description="Playlist de recomendados con mininos :D"
    )
    print(f"\n✅ Playlist creada: {playlist['name']} (" +
          f"{playlist['external_urls']['spotify']})")
    return playlist['id']

# Añadir canciones
def add_songs_to_playlist(playlist_id):
    df_songs = pd.read_csv(CSV_FILENAME)
    uris = df_songs["url"].tolist()
    if uris:
        sp.playlist_add_items(playlist_id, uris)
        print("\n🎶 Canciones añadidas correctamente.")
    else:
        print("⚠️ No se encontraron canciones en el CSV.")

# Generar portada con CATAAS
def generate_cover_image():
    print("\n🔄 Escogiendo al minino indicado con CATAAS...")
    cover_url = "https://cataas.com/cat?width=300&height=300"
    r = requests.get(cover_url)
    if r.status_code == 200:
        with open(IMAGE_PATH, "wb") as f:
            f.write(r.content)
        print(f"✅ Portada generada en: {IMAGE_PATH}")
    else:
        print("Error: No se pudo obtener imagen de cataas.com.")

# Subir portada
def upload_playlist_cover(playlist_id):
    with open(IMAGE_PATH, "rb") as f:
        encoded_image = base64.b64encode(f.read()).decode("utf-8")
    token = sp.auth_manager.get_access_token(as_dict=False)
    resp = requests.put(
        f"https://api.spotify.com/v1/playlists/{playlist_id}/images",
        headers={"Authorization": f"Bearer {token}", "Content-Type": "image/jpeg"},
        data=encoded_image
    )
    if resp.status_code == 202:
        print("\n✅ Portada actualizada correctamente.")

# Flujo principal
def main():
    user_id = get_user_info()
    generate_songs_csv()
    playlist_id = create_playlist(user_id)
    add_songs_to_playlist(playlist_id)
    generate_cover_image()
    upload_playlist_cover(playlist_id)
    print("\n🎉 Proceso completado.")

if __name__ == "__main__":
    main()
# Out:
# 🔒 Iniciando autenticación en Spotify...
#
# 🔎 Accediendo a URL de autorización...
#
# ✅ Autenticación completada.
#
# 👤 Usuario autenticado: Víctor Belinchón Pérez (https://open.spotify.com/user/1149089174)
#
# 🎵 Ingresa el nombre de la canción y el artista: Bad Bunny Yonaguni
#
# ✅ Encontrada en Last.fm: Yonaguni - Bad Bunny
# ✅ Encontrada en Spotify: Yonaguni - Bad Bunny
#
# 🔎 Canciones similares:
#
# Vete - Bad Bunny (https://open.spotify.com/track/2n7ohqg1s68ToAHh4u9mcW)
# Moscow Mule - Bad Bunny (https://open.spotify.com/track/6Xom58OOXk2SoU711L2IXO)
# Feliz Cumpleaños Ferxxo - Feid (https://open.spotify.com/track/2CeKVsFFXG4QzA415QygGb)
# CHORRITO PA LAS ANIMAS - Feid (https://open.spotify.com/track/0CYTGMBYkwUxrj1MWDLrC5)
# Cúrame - Rauw Alejandro (https://open.spotify.com/track/1FlL8ycld6uVDDyhV7P5FA)
# DILUVIO - Rauw Alejandro (https://open.spotify.com/track/2kz1YOhJiNubjigR1gB1VX)
# Holanda - JHAYCO (https://open.spotify.com/track/6irysuQyZWd7Bjj7ePiOs2)
# LALA - Myke Towers (https://open.spotify.com/track/7ABLbnD53cQK00mhcaOUVG)
# Columbia - Quevedo (https://open.spotify.com/track/6XbtvPmIpyCbjuT0e8cQtp)
# LA FALDA - Myke Towers (https://open.spotify.com/track/7iUtQNMRB8ZkKC4AmEuCJC)
# Se Preparó - Ozuna (https://open.spotify.com/track/1m69ELEgE6k5ZWsap40ozt)
# PUNTO G - Quevedo (https://open.spotify.com/track/4WiQA1AGWHFvaxBU6bHghs)
# La Santa - Bad Bunny, Daddy Yankee (https://open.spotify.com/track/69vlMrzHwATKzupwNcUPyK)
# Azul - J Balvin (https://open.spotify.com/track/2lCkncy6bIB0LTMT7kvrD1)
# La Despedida - Daddy Yankee (https://open.spotify.com/track/0fqrZVSenCW6vD2eFMx5pt)
# Lo Siento BB:/ - Tainy, Bad Bunny, Julieta Venegas (https://open.spotify.com/track/04x1x0L8BYyIv1XlcJxWfi)
# A Mí - Rels B (https://open.spotify.com/track/7MmrcXVA7A5zZ2CbDuGHNa)
# LA NOCHE DE ANOCHE - Bad Bunny, ROSALÍA (https://open.spotify.com/track/2XIc1pqjXV3Cr2BQUGNBck)
# PROVENZA - KAROL G (https://open.spotify.com/track/3HqcNJdZ2seoGxhn0wVNDK)
# Hawái - Maluma (https://open.spotify.com/track/1yoMvmasuxZfqHEipJhRbp)
# Rojo - J Balvin (https://open.spotify.com/track/380HmhwTE2NJgawn1NwkXi)
# Candy - Plan B (https://open.spotify.com/track/2ctjDCCg1wHoQSjIJ8p6U4)
# La Bachata - Manuel Turizo (https://open.spotify.com/track/3tt9i3Hhzq84dPS8H7iSiJ)
# Si No Le Contesto - Plan B (https://open.spotify.com/track/6NdKkfo7o6IH1Op0jsBDjN)
# El Perdedor - Maluma (https://open.spotify.com/track/1iEwyiSLAunPR6uouANE0O)
# Tokyo - JHAYCO (https://open.spotify.com/track/1gYipuSzUpI6BENbGrgeid)
# Lo Que Pasó, Pasó - Daddy Yankee (https://open.spotify.com/track/40a82F3K2UTbeoLlXXXZBd)
# Tal Vez - Paulo Londra (https://open.spotify.com/track/5jW3rF4URMdK7tO2xjS5EI)
# Salió El Sol - Don Omar (https://open.spotify.com/track/48NXpYRuvv9izul4oXhqS9)
# Dile - Don Omar (https://open.spotify.com/track/69Ej1xrGjOcHvIMtMKxK0G)
# AMARGURA - KAROL G (https://open.spotify.com/track/505v13epFXodT9fVAJ6h8k)
# Tuyo - Mora (https://open.spotify.com/track/4tQofG51E0juZBBVr6pral)
# Pa' Que La Pases Bien - Arcángel (https://open.spotify.com/track/1pLCpA1RN8avJxSD3ZCwhj)
# Caramelo - Remix - Ozuna, KAROL G, Myke Towers (https://open.spotify.com/track/67jvGGbJmOmVonlyX3mNkV)
# SI NO ES CONTIGO - Cris Mj (https://open.spotify.com/track/5Uptvz6j1sjDKxidAcnH2L)
# RUBICON - Peso Pluma (https://open.spotify.com/track/0xGZjxYqcNQ8WqxyeZ4eSN)
# Lollipop - Darell (https://open.spotify.com/track/3cDyocF0Ibdfs1SFQk5cLZ)
# Pa' Que Retozen - Tego Calderón (https://open.spotify.com/track/5YJ4BVvTFmVCxUyhKejHfR)
# BYE - Peso Pluma (https://open.spotify.com/track/6f8wbdo8KU5ETWJA7lapgS)
# Santa - Rvssian, Rauw Alejandro, Ayra Starr (https://open.spotify.com/track/6a9Z1jUms915w4O7N1PxjY)
# La Pregunta - J Alvarez (https://open.spotify.com/track/2Ob4mHihtOGbx6jnCredFX)
# Yo Voy (feat. Daddy Yankee) - Zion & Lennox (https://open.spotify.com/track/5gflgO9EPbIBf16n5TKnQS)
# Quiero Bailar - Ivy Queen (https://open.spotify.com/track/5JLV62rg4jtnoElc4P9F6K)
# Atrévete-Te-Te - Calle 13 (https://open.spotify.com/track/1q8NdCAQ9QUjpYiqzdd3mv)
# FANTASMA | AVC - Tainy, JHAYCO (https://open.spotify.com/track/0EZqBZknFKby6dk41hfi2o)
# LENTITO - Alvaro Diaz (https://open.spotify.com/track/5cqeTJhPAfHU4ROwcgG5L4)
# Ven Bailalo - Reggaeton Mix - Angel Y Khriz (https://open.spotify.com/track/0e8DgtfJnWTBarF9YGMd0N)
# Gato de Noche - Ñengo Flow, Bad Bunny (https://open.spotify.com/track/54ELExv56KCAB4UP9cOCzC)
# Escápate Conmigo (feat. Ozuna) - Wisin, Ozuna (https://open.spotify.com/track/1KSqYYJFyfTecXFk9M0prc)
#
# 📁 CSV generado en: songs_recommendations.csv
#
# 📋 Nombre de la nueva playlist: Sabroseo
#
# ✅ Playlist creada: Sabroseo (https://open.spotify.com/playlist/4SxocgRpkJOGVZUBEsbUcj)
#
# 🎶 Canciones añadidas correctamente.
#
# 🔄 Escogiendo al minino indicado con CATAAS...
# ✅ Portada generada en: michis.jpg
#
# ✅ Portada actualizada correctamente.
#
# 🎉 Proceso completado.
